# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import tensorflow
import keras
import cv2
import csv

# %matplotlib inline
from matplotlib import pyplot as plt

# %%
# %cd /content/drive/My Drive/tfg/

# !git clone https://github.com/fizyr/keras-retinanet.git

# %cd /content/drive/My Drive/tfg/keras-retinanet/

# !pip install numpy

# !pip install .

# !python setup.py build_ext --inplace

# !wget https://github.com/fizyr/keras-retinanet/releases/download/0.5.1/resnet50_coco_best_v2.1.0.h5

# %%
# %cd /content/drive/My Drive/tfg/keras-retinanet/keras_retinanet/

# !chmod 755 /bin/

# %%
# %cd /content/drive/My Drive/tfg/keras-retinanet/

# !python keras_retinanet/bin/train.py --tensorboard-dir tensorboard/ --config config/config.ini --weights snapshots/resnet50_csv_10.h5 --batch-size 1 --steps 3017 --epochs 10 csv train_labels2.csv classes.csv

# %%
# %cd /content/drive/My Drive/tfg/keras-retinanet/
# !python keras_retinanet/bin/convert_model.py snapshots/resnet50_csv_10.h5 snapshots/resnet50_MODEL30.h5 --config config/config.ini

# %%
# %cd /content/drive/My Drive/tfg/keras-retinanet/

# !chmod 755 results/

# !python keras_retinanet/bin/evaluate.py --iou-threshold 0.7 --score-threshold 0.8 --save-path results/ csv test_labels.csv classes.csv snapshots/resnet50_MODEL30.h5
